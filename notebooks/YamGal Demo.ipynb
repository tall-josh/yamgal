# %% [markdown]
# # YamGal Demo
#
#
# ## From Public Github
#
# `https://github.com/tall-josh/yamgal/blob/master/examples/lines-01.yaml`
#
# **Drop the `https://`**
#
# `github.com/tall-josh/yamgal/blob/master/examples/lines-01.yaml`
#
# **Yamgal** does the rest
#
# `![<alt text](http://yamgal.com/github.com/tall-josh/yamgal/blob/master/examples/lines-01.yaml)`
#
# ---
#
# `![demo chart](http://127.0.0.1:5000/yamgal/github.com/tall-josh/yamgal/blob/master/examples/lines-01.yaml)`
#
# ![demo chart](https://yamlgal-py3-alpine-c6l3dwv2sq-de.a.run.app/yamgal/github.com/tall-josh/yamgal/blob/master/examples/lines-01.yaml?121)

# %% [markdown]
# ## From Pirvate GitLab
#
# **https Repo URL**
#
# `https://gitlab.com/silverpond/research/dvc-jupyter-project-example-demo.git`
#
# **Drop the `https://`**
#
# `gitlab.com/silverpond/research/dvc-jupyter-project-example-demo.git`
#
# **Add relitave path to file in repo**
#
# `gitlab.com/silverpond/research/dvc-jupyter-project-example-demo.git/artefacts/example-metric.yaml`
#
# **Yamgal** does the rest
#
# `![<alt text](http://yamgal.com/gitlab.com/silverpond/research/dvc-jupyter-project-example-demo.git/artefacts/example-metric.yaml)`
#
# ---
#
# `![demo chart](http://127.0.0.1:5000/yamgal/gitlab.com/silverpond/research/dvc-jupyter-project-example-demo.git/artefacts/example-metric.yaml)`
#
# ![demo chart](http://localhost:8080/yamgal/gitlab.com/silverpond/research/dvc-jupyter-project-example-demo.git/artefacts/example-metric.yaml?123)

# %% [markdown]
# ## Line Charts
#
# ![demo line](http://localhost:8080/yamgal/local/examples/line.yaml?3)
#
#
# ## XY Charts
#
# ### With Stroke
#
# ![demo xy](http://localhost:8080/yamgal/local/examples/xy.yaml?3)
#
# ### Without Stroke
# ![demo xy no stroke](http://localhost:8080/yamgal/local/examples/xy_stroke_off.yaml?3)
#
# ## Bar Charts
#
# ![demo bar](http://localhost:8080/yamgal/local/examples/bar.yaml?3)
#
# ![demo stacked bar](http://localhost:8080/yamgal/local/examples/stacked_bar.yaml?3)
#
# ![demo horizontal bar](http://localhost:8080/yamgal/local/examples/horizontal_bar.yaml?3)
#
#
# ## Histogram
#
# ![demo histogram](http://localhost:8080/yamgal/local/examples/bar.yaml?3)
#
#
# ## Pie Charts
#
# ### Simple Pie
#
# ![demo pie](http://localhost:8080/yamgal/local/examples/pie.yaml?3)
#
#
# ### Multi Series Pie
#
# ![demo pie](http://localhost:8080/yamgal/local/examples/pie_multi_series.yaml?3)
#
#
# ### Donut Pie
#
# ![demo pie](http://localhost:8080/yamgal/local/examples/pie_donut.yaml?3)
#
# ### Half Pie
#
# ![demo pie](http://localhost:8080/yamgal/local/examples/pie_half.yaml?3)
#
# ## Styles
#
# ### Default
#
# ![demo pie](http://localhost:8080/yamgal/local/examples/style_default.yaml?3)
#
# ### Default
#
# ![demo pie](http://localhost:8080/yamgal/local/examples/style_default.yaml?3)
#
# ### Blue
#
# ![demo pie](http://localhost:8080/yamgal/local/examples/style_blue.yaml?3)
#
# ### Clean
#
# ![demo pie](http://localhost:8080/yamgal/local/examples/style_clean.yaml?3)
#
# ### Dark Colorized
#
# ![demo pie](http://localhost:8080/yamgal/local/examples/style_dark_colorized.yaml?3)
#
# ### Dark Green Blue
#
# ![demo pie](http://localhost:8080/yamgal/local/examples/style_dark_green_blue.yaml?3)
#
# ### Dark Green
#
# ![demo pie](http://localhost:8080/yamgal/local/examples/style_dark_green.yaml?3)
#
# ### Dark Solarized
#
# ![demo pie](http://localhost:8080/yamgal/local/examples/style_dark_solarized.yaml?3)
#
# ### Dark
#
# ![demo pie](http://localhost:8080/yamgal/local/examples/style_dark.yaml?3)
#
# ### Light Colorized
#
# ![demo pie](http://localhost:8080/yamgal/local/examples/style_light_colorized.yaml?3)
#
# ### Light Green
#
# ![demo pie](http://localhost:8080/yamgal/local/examples/style_light_green.yaml?3)
#
# ### Light Solarized
#
# ![demo pie](http://localhost:8080/yamgal/local/examples/style_light_solarized.yaml?3)
#
# ### Light
#
# ![demo pie](http://localhost:8080/yamgal/local/examples/style_light.yaml?3)
#
# ### Neon
#
# ![demo pie](http://localhost:8080/yamgal/local/examples/style_neon.yaml?3)
#
# ### Red Blue
#
# ![demo pie](http://localhost:8080/yamgal/local/examples/style_reb_blue.yaml?3)
#
# ### Turquoise
#
# ![demo pie](http://localhost:8080/yamgal/local/examples/style_turquoise.yaml?3)
